# %%
import matplotlib.pyplot as plt
import random
def find_max(my_list):
    max_value = my_list[0]
    step = 0
    for i in range(len(my_list)):
        step += 1
        if my_list[i] > max_value:
            max_value = my_list[i]
 
    return max_value,step
n = [10, 100, 500, 1000, 1500, 2000, 3000, 5000]
n_step = []
for i in n:
    list = random.sample(range(0,i), i)
    x,step = find_max(list)
    n_step.append(step)
    plt.plot(n_step)
    plt.show()
    print(n_step)
# Out:
# [10]
# [10, 100]
# [10, 100, 500]
# [10, 100, 500, 1000]
# [10, 100, 500, 1000, 1500]
# [10, 100, 500, 1000, 1500, 2000]
# [10, 100, 500, 1000, 1500, 2000, 3000]
# [10, 100, 500, 1000, 1500, 2000, 3000, 5000]

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0, 0.5, 1000)
f1 = 10
f2 = 1000
x1 = np.cos(2 * np.pi * f1 * t)
x2 = np.cos(2 * np.pi * f2 * t)
fs = 40
Ts = 1/fs
n = np.arange(0,0.5*fs)
nT = n*Ts
x1n = np.cos(2 * np.pi * f1 * nT)
x2n = np.cos(2 * np.pi * f2 * nT)
plt.figure(figsize=(20, 8))
plt.plot(t,x1,color='orange',label='x1(t): 10 Hz')
plt.plot(t,x2,color='violet',label='x2(t): 50 Hz')

plt.title('Aliasing Condition (Fs = 40Hz)')
plt.xlabel('time', fontsize=15)
plt.ylabel('Amplitude', fontsize=15)
plt.legend(fontsize=10, loc='upper right')
plt.show()

# %%
plt.plot(nT, x1n, 'red', label='x1(n): 10 Hz')
plt.plot(nT, x2n, 'darkmagenta',label='x2(n): 50 Hz')
plt.title('Aliasing Condition (Fs = 40Hz)')
plt.xlabel('time', fontsize=15)
plt.ylabel('Amplitude', fontsize=15)
plt.legend(fontsize=10, loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0, 0.5, 1000)
f1 = 10
f2 = 50
x = np.cos(2 * np.pi * f1 * t)+np.cos(2 * 
np.pi * f2 * t)
fs = 200
Ts = 1/fs
n = np.arange(0,0.5*fs)
nT = n*Ts
xn = np.cos(2 * np.pi * f1 * nT)+np.cos(2 * 
np.pi * f2 * nT)
frs1 = signal.resample(xn,50)
xn_resample1 = np.linspace(0,0.5,50)
frs2 = signal.resample(xn,300)
xn_resample2 = np.linspace(0,0.5,300)
plt.figure(figsize=(20, 10))
plt.subplot(3,1,1)
plt.title('Sampling and Recontruction of Cos Waves 10+40Hz 
by Fs = 200 Hz')
plt.plot(t, x,color='skyblue',label='x(t)')
plt.legend(fontsize=10, loc='upper right')
plt.ylabel('Amplitude', fontsize=15)
plt.subplot(3,1,2)
plt.stem(nT, xn, 'steelblue', markerfmt='o', label='x(n)')
plt.stem(xn_resample1, frs1, 'plum',markerfmt='D', 
label='Resample 50 Hz')
plt.stem(xn_resample2, frs2, 
'mediumaquamarine',markerfmt='x', label='Resample 300 Hz')
plt.legend(fontsize=10, loc='upper right')
plt.ylabel('Amplitude', fontsize=15)
plt.subplot(3,1,3)
plt.plot(nT, xn, 'midnightblue', label='Reconstructed 
sampled by 200Hz')
plt.plot(xn_resample1, frs1, 'rebeccapurple', 
label='Reconstructed resampled digital signal by 50 Hz')
plt.plot(xn_resample2, frs2, 'darkgreen', 
label='Reconstructed resampled digital signal by 300Hz')
plt.legend(fontsize=10, loc='upper right')
plt.xlabel('time', fontsize=15)
plt.ylabel('Amplitude', fontsize=15)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0, 0.5, 1000)
f1 = 100
f2 = 50
x1 = np.cos(2 * np.pi * f1 * t)
x2 = np.cos(2 * np.pi * f2 * t)
fs = 200
Ts = 1/fs
n = np.arange(0,0.5*fs)
nT = n*Ts
x1n = np.cos(2 * np.pi * f1 * nT)
x2n = np.cos(2 * np.pi * f2 * nT)
plt.figure(figsize=(20, 8))
plt.plot(t,x1,color='orange',label='x1(t): 10 Hz')
plt.plot(t,x2,color='violet',label='x2(t): 50 Hz')

plt.title('Non-Aliasing Condition (Fs = 200 Hz)')
plt.xlabel('time', fontsize=15)
plt.ylabel('Amplitude', fontsize=15)
plt.legend(fontsize=10, loc='upper right')
plt.show()

# %%
plt.plot(nT, x1n, 'red', label='x1(n): 10 Hz')
plt.plot(nT, x2n, 'darkmagenta',label='x2(n): 50 Hz')
plt.title('Non-Aliasing Condition (Fs = 200 Hz)')
plt.xlabel('time', fontsize=15)
plt.ylabel('Amplitude', fontsize=15)
plt.legend(fontsize=10, loc='upper right')
plt.show()

# %%
print(len(t))
print(len(x1))
# Out:
# 1000
# 1000
