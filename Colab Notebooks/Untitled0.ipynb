# %%
  sayur = ['Bayam', 'Wortel', 'Tomat', 'Terong']
  harga_sayur = [5000, 6000, 3500, 9000]
  for val1, val2 in zip(sayur,harga_sayur):
    print(f'{val1} harganya adalah {val2}')
# Out:
# Bayam harganya adalah 5000
# Wortel harganya adalah 6000
# Tomat harganya adalah 3500
# Terong harganya adalah 9000
