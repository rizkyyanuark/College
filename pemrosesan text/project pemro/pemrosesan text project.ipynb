# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install nltk
# !pip install PySastrawi
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Collecting PySastrawi
#   Downloading PySastrawi-1.2.0-py2.py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.6/210.6 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: PySastrawi
# Successfully installed PySastrawi-1.2.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import csv
import numpy as np
import seaborn as sns
from time import time
from datetime import datetime as dt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from wordcloud import WordCloud
import gensim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
import joblib
from time import time
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import json
import reprlib
import os

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
file_loc = "/content/drive/MyDrive/pemrosesan text/project/combined_data.csv"
dataset = pd.read_csv(file_loc)
dataset = dataset.iloc[:, :12]
dataset = dataset[dataset.iloc[:, 7] == 'in']
dataset
# Out:
#        Mon Nov 06 23:07:13 +0000 2023  1.72167E+18  \
# 0      Mon Nov 06 23:05:07 +0000 2023  1.72167E+18
# 1      Mon Nov 06 15:39:36 +0000 2023  1.72155E+18
# 2      Mon Nov 06 16:50:10 +0000 2023  1.72157E+18
# 3      Mon Nov 06 16:12:14 +0000 2023  1.72156E+18
# 4      Mon Nov 06 16:02:17 +0000 2023  1.72156E+18
# ...                               ...          ...
# 13602  Wed Aug 30 14:19:05 +0000 2023  1.69689E+18
# 13603  Wed Aug 30 14:14:58 +0000 2023  1.69689E+18
# 13604  Wed Aug 30 14:10:57 +0000 2023  1.69689E+18
# 13605  Wed Aug 30 14:10:18 +0000 2023  1.69689E+18
# 13606  Wed Aug 30 14:07:44 +0000 2023  1.69689E+18
#
#       No indication yet that LRT Jabodebek is putting trainsets repaired trainsets back to work. Maintenance should last 5-7 days per trainset as announced earlier so 1 or 2 trainsets should have been back operating now. But no nothing about that. More problems? #LRTJabodebek  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13602  Pantas saja Budiman gabung prabowo untuk cari ...
# 13603  kek produk beta: (-) pendek banget gw harus nu...
# 13604  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13605  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13606  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#        0 0.1 0.2  1  en  1.22449E+18 1.72167E+18.1     johanstravel  \
# 0      0   0   0  2  in  1.22449E+18   1.72153E+18     johanstravel
# 1      0   0   0  0  in    135795460   1.72155E+18     detikfinance
# 2      0   1   0  0  in   1065117618   1.72154E+18        farizies_
# 3      0   0   0  0  in    550032230   1.72156E+18           wnrzky
# 4      0   0   0  0  in  1.33479E+18   1.72156E+18       ygsdgrindu
# ...   ..  ..  .. ..  ..          ...           ...              ...
# 13602  0   1   0  1  in   1.6199E+18   1.69689E+18         Lop3Lop3
# 13603  0   1   0  0  in   4520387374   1.69689E+18    flowers4cntwl
# 13604  0   0   0  0  in  1.64256E+18   1.69689E+18        ning_imas
# 13605  0   0   0  3  in  1.68984E+18   1.69689E+18      ssandika747
# 13606  0   0   1  1  in  1.64062E+18   1.69689E+18  singgihhmaulana
#
#       https://twitter.com/johanstravel/status/1721665570075193837
# 0      https://twitter.com/johanstravel/status/172166...
# 1      https://twitter.com/detikfinance/status/172155...
# 2      https://twitter.com/farizies_/status/172157068...
# 3      https://twitter.com/wnrzky/status/172156113716...
# 4      https://twitter.com/ygsdgrindu/status/17215586...
# ...                                                  ...
# 13602  https://twitter.com/Lop3Lop3/status/1696890285...
# 13603  https://twitter.com/flowers4cntwl/status/16968...
# 13604  https://twitter.com/ning_imas/status/169688823...
# 13605  https://twitter.com/ssandika747/status/1696888...
# 13606  https://twitter.com/singgihhmaulana/status/169...
#
# [11768 rows x 12 columns]

# %%
dataset.columns = ["Date", "user", "Tweet",'1','2','3','4','5','6','7','8','9']  # Ganti dengan nama header yang Anda inginkan

# Hapus semua kolom kecuali 'Tweet'
dataset = dataset[['Date','Tweet']]
dataset = dataset.drop_duplicates()
dataset
# Out:
#                                  Date  \
# 0      Mon Nov 06 23:05:07 +0000 2023
# 1      Mon Nov 06 15:39:36 +0000 2023
# 2      Mon Nov 06 16:50:10 +0000 2023
# 3      Mon Nov 06 16:12:14 +0000 2023
# 4      Mon Nov 06 16:02:17 +0000 2023
# ...                               ...
# 13391  Wed Aug 30 14:19:05 +0000 2023
# 13392  Wed Aug 30 14:14:58 +0000 2023
# 13393  Wed Aug 30 14:10:57 +0000 2023
# 13394  Wed Aug 30 14:10:18 +0000 2023
# 13395  Wed Aug 30 14:07:44 +0000 2023
#
#                                                    Tweet
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
# [8766 rows x 2 columns]

# %%
jumlah_tweet = dataset["Tweet"].count()
print(f"Jumlah tweet: {jumlah_tweet}")
# Out:
# Jumlah tweet: 8766

# %%
dataset.loc[10, 'Tweet']
# Out:
# '@lrtjabodebek Min tolong eskalator di dukuh atas dibenerin 😁😅'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Misalkan 'dataset' adalah DataFrame Anda
tweets = dataset.copy()

# Ubah format 'Date' menjadi datetime
tweets['Date'] = pd.to_datetime(tweets['Date'], format='%a %b %d %H:%M:%S +0000 %Y')

# Ekstrak bulan dan tahun dari 'Date' dan buat kolom baru 'YearMonth'
tweets['YearMonth'] = tweets['Date'].dt.to_period('M')

# Hitung jumlah tweet per bulan
monthly_tweets = tweets.groupby('YearMonth').size()

# Buat daftar warna untuk grafik batang
colors = plt.cm.viridis(np.linspace(0, 1, len(monthly_tweets)))

# Plot jumlah tweet per bulan dengan warna
monthly_tweets.plot(kind='bar', figsize=(10, 5), color=colors)

plt.xlabel("Bulan dan Tahun")
plt.ylabel("Jumlah Tweet")
plt.title("Jumlah Tweet per Bulan")
plt.grid(True)
plt.show()
dataset = dataset[['Tweet']]

# %%
alay_dict = pd.read_csv('/content/drive/MyDrive/pemrosesan text/project/new_kamusalay.csv', encoding='latin-1', header=None)
alay_dict = alay_dict.rename(columns={0: 'original',
                                      1: 'replacement'})

# %%
# Read the CSV file and specify the separator as ';'
alay_dict2 = pd.read_csv('/content/drive/MyDrive/pemrosesan text/project/kamus_singkatan_deluxe.csv', sep=';',encoding='latin-1')

# Set the column names
alay_dict2.columns = ['original', 'replacement']
alay_dict_map2 = dict(zip(alay_dict2['original'], alay_dict2['replacement']))
alay_dict2.head()
# Out:
#   original replacement
# 0     adek       adik
# 1     adlh     adalah
# 2      aer        air
# 3  aiskrim    es krim
# 4       aj       saja

# %%
def lowercase(text):
    if isinstance(text, str):
        return text.lower()
    else:
        return text

dataset["preprocessed"] = dataset.Tweet.apply(lambda text: lowercase(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      @lrtjabodebek selain posting jadwal yg kacau i...
# 1      volume atau jumlah penumpang krl commuter line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      sekelas @cnbcindonesia @cnnindonesia masih bel...
# 4      tarif lrt jabodebek dijamin gak naik tahun ini...
# ...                                                  ...
# 13391  pantas saja budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  blue moon #viralvideo mahasiswa fisip ui inka ...
# 13394  setelan tunik wanita hijab bahan babytery http...
# 13395  ganjar bakal terus mbangun ikn lan hilirisasi ...
#
# [8766 rows x 2 columns]

# %%
def remove_link(text):
    text = re.sub('https?://t\.me/[^\s]+', ' ', text) # Menghapus setiap link Telegram
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', ' ', text) # Menghapus setiap url
    return text

dataset["preprocessed"] = dataset.preprocessed.astype(str).apply(lambda text: remove_link(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      @lrtjabodebek selain posting jadwal yg kacau i...
# 1      volume atau jumlah penumpang krl commuter line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      sekelas @cnbcindonesia @cnnindonesia masih bel...
# 4      tarif lrt jabodebek dijamin gak naik tahun ini...
# ...                                                  ...
# 13391  pantas saja budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  blue moon #viralvideo mahasiswa fisip ui inka ...
# 13394  setelan tunik wanita hijab bahan babytery   bl...
# 13395  ganjar bakal terus mbangun ikn lan hilirisasi ...
#
# [8766 rows x 2 columns]

# %%
def transform_emoticons(text):
    text = text.replace("<3", "<love>")
    text = text.replace(":p", "<mengejek>")
    text = text.replace(":P", "<mengejek>")
    text = text.replace(":v", "<melucu>")
    text = text.replace(":V", "<melucu>")
    text = text.replace(":d", "<tertawa>")
    text = text.replace(":D", "<tertawa>")
    text = text.replace(":-D", "<tertawa>")
    text = text.replace(":o", "<terkejut>")
    text = text.replace(":O", "<terkejut>")
    text = text.replace("xD", "<tertawa terbahak bahak>")
    text = text.replace("XD", "<tertawa terbahak bahak>")
    text = text.replace(":*", "<mencium>")
    text = text.replace(":3", "<malu malu kucing>")
    text = text.replace("-__-", "<wajah datar>")
    text = text.replace("-_-", "<wajah datar>")
    text = text.replace(":|", "<wajah datar>")
    text = text.replace(":\\", "<terganggu>")
    text = text.replace(":/", "<terganggu>")
    text = text.replace(":))", "<senyum>")
    text = text.replace(":)", "<senyum>")
    text = text.replace(":-))", "<senyum>")
    text = text.replace(":-)", "<senyum>")
    text = text.replace("^^", "<senyum>")
    text = text.replace("^_^", "<senyum>")
    text = text.replace(";))", "<senyum berkedip>")
    text = text.replace(";)", "<senyum berkedip>")
    text = text.replace(":((", "<sedih>")
    text = text.replace(":(", "<sedih>")
    text = text.replace(":-((", "<sedih>")
    text = text.replace(":-(", "<sedih>")
    text = text.replace(":'((", "<menangis sedih>")
    text = text.replace(":'(", "<menangis sedih>")
    text = text.replace(":'))", "<menangis bahagia>")
    text = text.replace(":')", "<menangis bahagia>")
    text = text.replace(":'", "<menangis sedih>")
    text = text.replace(":’((", "<menangis sedih>")
    text = text.replace(":’(", "<menangis sedih>")
    text = text.replace(":’))", "<menangis bahagia>")
    text = text.replace(":’)", "<menangis bahagia>")
    text = text.replace(":’", "<menangis sedih>")
    text = text.replace(":\"((", "<menangis sedih>")
    text = text.replace(":\"(", "<menangis sedih>")
    text = text.replace(":\"))", "<menangis bahagia>")
    text = text.replace(":\")", "<menangis bahagia>")
    text = text.replace(":\"", "<menangis sedih>")
    text = text.replace(":\"D", "<menangis bahagia>")
    text = text.replace("TT", "<menangis sedih>")
    return text
dataset["preprocessed"] = dataset.preprocessed.apply(lambda text: transform_emoticons(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      @lrtjabodebek selain posting jadwal yg kacau i...
# 1      volume atau jumlah penumpang krl commuter line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      sekelas @cnbcindonesia @cnnindonesia masih bel...
# 4      tarif lrt jabodebek dijamin gak naik tahun ini...
# ...                                                  ...
# 13391  pantas saja budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  blue moon #viralvideo mahasiswa fisip ui inka ...
# 13394  setelan tunik wanita hijab bahan babytery   bl...
# 13395  ganjar bakal terus mbangun ikn lan hilirisasi ...
#
# [8766 rows x 2 columns]

# %%
# Membuat kamus penggantian emoji ke teks
emoji_dict = {
    '🙏🏻': 'maaf',
    '🙏': 'maaf',
    '👍': 'baik',
    '👍🏽': 'baik',
    '🥺': 'mata sedih',
    '💕': 'cinta',
    '🤩': 'mata berbinar',
    '😭': 'tangis',
    '🥲': 'sedih',
    '😆': 'tawa teriak',
    '👏🏻': 'tepuk tangan',
    '🧐': 'pikir',
    '🙃': 'senyum',
    '😃': 'senang',
    '😊': 'senyum',
    '👀': 'mata lihat',
    '👮🏻': 'polisi',
    '😂': 'tawa lucu',
    '🤣': 'tawa lucu',
    '💃🏼': 'menari',
    '😫': 'lelah',
    '🤍': 'cinta putih',
    '😖': 'frustasi',
    '📥': 'kotak masuk',
    '📱': 'ponsel',
    '📍': 'lokasi',
    '😠': 'marah',
    '😤': 'kesal',
    '🤭': 'tawa malu',
    '🥰': 'sayang',
    '🤧': 'tangis sedih',
    '💙': 'cinta biru',
    '🎇': 'kembang api',
    '🥂': 'sulang',
    '👍🏼': 'baik',
    '😌': 'tenang',
    '🙏🏼': 'maaf',
    '🙌': 'hore',
    '😙': 'santai',
    '🌻': 'bunga matahari',
    '😳': 'malu',
    '💪': 'kuat',
    '🙂': 'senyum',
    '👋': 'hai',
    '😻': 'mata jatuh cinta',
    '🚗': 'mobil',
    '🗓': 'kalender',
    '👎': 'tidak suka',
    '🍻': 'minum',
    '👭': 'dua perempuan',
    '💻': 'laptop',
    '📢': 'pengumuman',
    '😱': 'kaget',
    '🙏🏿': 'maaf',
    '😄': 'tawa gembira',
    '😉': 'kedip satu mata',
    '🤗': 'wajah sayang',
    '🤬': 'marah kesal',
    '🏼': 'kulit cerah',
    '🙋': 'angkat tangan',
    '🩸': 'darah',
    '😎': 'keren',
    '🤲': 'doa',
    '😬': 'canggung',
    '😍': 'wajah cinta',
    '👌': 'oke',
    '🎉': 'pesta',
    '🤝': 'jabat tangan',
    '😔': 'kecewa',
    '😒': 'kesal',
    '👏': 'tepuk tangan',
    '🏷': 'label',
    '🥳': 'suka ria',
    '🏞': 'panorama',
    '🙌🏻': 'hore',
    '😕': 'bimbang',
    '😅': 'tawa canggung',
    '🤡': 'badut',
    '😇': 'tulus',
    '🔍': 'cari',
    '🤤': 'giur',
    '🧕🏻': 'perempuan kerudung',
    '👳🏼': 'laki sorban',
    '🍧': 'es krim',
    '🚀': 'roket',
    '🤫': 'rahasia',
    '🔥': 'api',
    '😐': 'wajah netral',
    '📣': 'pengumuman',
    '👌🏼': 'ok',
    '💔': 'patah hati',
    '👦': 'anak laki',
    '👩': 'wanita',
    '🙇🏻': 'sesal',
    '😁': 'tawa',
    '😋': 'lezat',
    '🧔': 'pria',
    '🧑': 'orang',
    '💥': 'ledak',
    '👩🏻': 'wanita',
    '🏫': 'gedung sekolah',
    '👨🏻': 'pria',
    '💗': 'cinta',
    '👇': 'tunjuk bawah',
    '👆': 'tunjuk atas',
    '🚨': 'darurat',
    '🔊': 'bunyi keras',
    '🌈': 'pelangi',
    '😪': 'lelah',
    '😚': 'bibir moncong',
    '📕': 'buku',
    '😝': 'ejek julur lidah',
    '😞': 'sedih murung',
    '📸': 'foto',
    '🤮': 'muntah',
    '🤏🏼': 'kecil gemas',
    '📎': 'klip',
    '🕗': 'jam',
    '🥴': 'muak',
    '📈': 'tingkat',
    '😥': 'cemas',
    '😘': 'cium',
    '📙': 'buku',
    '📞': 'telepon',
    '🪀': 'bola piring',
    '🧑🏼': 'orang',
    '🧠': 'otak',
    '🚮': 'buang',
    '🎊': 'pesta',
    '🧓': 'pria tua',
    '😏': 'remeh',
    '🤪': 'konyol',
    '🙆': 'angkat dua tangan',
    '🌙': 'bulan sabit',
    '💛': 'cinta kuning',
    '💡': 'lampu',
    '📑': 'dokumen',
    '🕌': 'masjid',
    '🙏🏽': 'maaf',
    '💓': 'cinta',
    '🤙🏻': 'asik',
    '😵': 'pusing',
    '🔫': 'tembak',
    '💪🏻': 'kuat',
    '👧': 'anak perempuan',
    '👦': 'anak laki',
    '💜': 'cinta ungu',
    '🛎': 'bel',
    '📲': 'ponsel',
    '💳': 'kartu kredit',
    '🖤': 'cinta hitam',
    '📅': 'kalender',
    '💰': 'uang',
    '💌': 'surat cinta',
    '🤲🏻': 'doa',
    '👍🏿': 'baik',
    '🐉': 'naga',
    '🙆🏻': 'angkat dua tangan',
    '🖐': 'angkat tangan',
    '📝': 'tulis',
    '📖': 'buku',
    '🏆': 'piala juara',
    '🎓': 'wisuda',
    '🤌🏼': 'diam',
    '👉🏻': 'tunjuk kanan',
    '👈🏻': 'tunjuk kiri',
    '🌿': 'daun',
    '😺': 'kucing ceria',
    '🙁': 'sedih',
    '💧': 'tetes air',
    '💸': 'uang',
    '👤': 'orang',
    '👉': 'tunjuk kanan',
    '👈': 'tunjuk kiri',
    '👋🏻': 'hai',
    '📋': 'dokumen',
    '😑': 'bosan',
    '🎰': 'mesin untung',
    '🌟': 'bintang',
    '📚': 'buku',
    '🤷🏻': 'tidak tau',
    '🤒': 'demam',
    '💖': 'cinta',
    '😾': 'kucing kesal',
    '🖱': 'mouse komputer',
    '🎙': 'mikrofon',
    '🤚': 'angkat tangan',
    '🎤': 'mikrofon',
    '🥪': 'roti lapis',
    '💎': 'berlian',
    '🏅': 'medali',
    '🎮': 'kontrol mainan',
    '👵': 'wanita tua',
    '🥇': 'medali juara satu',
    '📌': 'semat',
    '🗳': 'kotak suara',
    '🙈': 'monyet malu',
    '🌏': 'dunia',
    '🕑': 'jam',
    '🖇': 'klip',
    '🙌🏼': 'hore',
    '🔴': 'lingkaran merah',
    '👧🏻': 'anak perempuan',
    '👱🏻': 'pria',
    '👨': 'pria',
    '🦳': 'pria tua',
    '🕐': 'jam',
    '💁🏼': 'angkat tangan',
    '💁🏻': 'angkat tangan',
    '🌠': 'bintang',
    '😶': 'tanpa ekspresi',
    '👐🏻': 'tangan terbuka',
    '👁👄👁': 'cengang',
    '🙇': 'sesal',
    '🤙': 'keren',
    '😛': 'ejek julur lidah',
    '😣': 'cemas',
    '🤦': 'bodoh',
    '🥘': 'makanan',
    '🍹': 'minuman',
    '🤟': 'keren',
    '🗣': 'suara keras',
    '🏮': 'lampion merah',
    '🐃': 'banteng',
    '🧧': 'angpao',
    '💯': 'seratus',
    '🥈': 'medali juara dua',
    '🥉': 'medali juara tiga',
    '😓': 'murung lelah',
    '🤜': 'tangan kepal setuju',
    '🌝': 'wajah bulan',
    '🖐🏻': 'angkat tangan',
    '🎭': 'topeng',
    '😜': 'ejek julur lidah',
    '🙄': 'kesal heran',
    '😖': 'ragu',
    '🤘': 'keren',
    '📩': 'pesan masuk'
}

# Fungsi untuk mengubah emoji ke teks
def emoji_to_text(text):
    for emoji, replacement in emoji_dict.items():
        text = text.replace(emoji, replacement)
    return text

# Terapkan fungsi ke kolom preprocessed
dataset["preprocessed"] = dataset.preprocessed.apply(lambda text: emoji_to_text(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      @lrtjabodebek selain posting jadwal yg kacau i...
# 1      volume atau jumlah penumpang krl commuter line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      sekelas @cnbcindonesia @cnnindonesia masih bel...
# 4      tarif lrt jabodebek dijamin gak naik tahun ini...
# ...                                                  ...
# 13391  pantas saja budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  blue moon #viralvideo mahasiswa fisip ui inka ...
# 13394  setelan tunik wanita hijab bahan babytery   bl...
# 13395  ganjar bakal terus mbangun ikn lan hilirisasi ...
#
# [8766 rows x 2 columns]

# %%
def remove_unnecessary_char(text):
    text = re.sub(r'@[\w]+', '', text) # menghapus username
    text = re.sub('  +', ' ', text) # Menghapus spasi ekstra
    text = re.sub('\n', ' ', text) # Menghapus setiap '\n'
    text = re.sub(r'\brt\b', ' ', text) # Menghapus setiap simbol retweet
    text = re.sub ('[^0-9a-zA-Z]+', ' ', text) # menghapus non aplhanumeric
    text = re.sub(r'\d+', '', text) # menghapus semua angka
    return text

dataset["preprocessed"] = dataset.preprocessed.apply(lambda text: remove_unnecessary_char(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0       selain posting jadwal yg kacau ini tolong upd...
# 1      volume atau jumlah penumpang krl commuter line...
# 2       sebenarnya bukan naik krl sih kalau habis nai...
# 3      sekelas masih belom bisa bedain gambar mana lr...
# 4      tarif lrt jabodebek dijamin gak naik tahun ini...
# ...                                                  ...
# 13391  pantas saja budiman gabung prabowo untuk cari ...
# 13392  kek produk beta pendek banget gw harus nunduk ...
# 13393  blue moon viralvideo mahasiswa fisip ui inka r...
# 13394  setelan tunik wanita hijab bahan babytery blue...
# 13395  ganjar bakal terus mbangun ikn lan hilirisasi ...
#
# [8766 rows x 2 columns]

# %%
def remove_stopword(text):
    stop_words = set(stopwords.words('indonesian'))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word not in stop_words]
    return ' '.join(filtered_text)

dataset["preprocessed"] = dataset.preprocessed.apply(lambda text: remove_stopword(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      posting jadwal yg kacau tolong update ttg trai...
# 1      volume penumpang krl commuter line meningkat k...
# 2      krl sih habis kereta cepat whoosh naiknya lrt ...
# 3      sekelas belom bedain gambar lrt jakarta lrt ja...
# 4                 tarif lrt jabodebek dijamin gak segini
# ...                                                  ...
# 13391  budiman gabung prabowo cari cuan lunasin hutan...
# 13392  kek produk beta pendek banget gw nunduk rem ga...
# 13393  blue moon viralvideo mahasiswa fisip ui inka r...
# 13394  setelan tunik wanita hijab bahan babytery blue...
# 13395  ganjar mbangun ikn lan hilirisasi warisan joko...
#
# [8766 rows x 2 columns]

# %%
alay_dict_map = dict(zip(alay_dict['original'], alay_dict['replacement']))
def normalize_alay(text):
    return ' '.join([alay_dict_map[word] if word in alay_dict_map else word for word in text.split(' ')])
dataset["preprocessed"] = dataset.preprocessed.apply(lambda text: normalize_alay(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      posting jadwal yang kacau tolong pembaruan ten...
# 1      volume penumpang kereta listrik commuter line ...
# 2      kereta listrik sih habis kereta cepat whoosh n...
# 3      sekelas belum bedakan gambar light rail transi...
# 4      tarif light rail transit jabodebek dijamin tid...
# ...                                                  ...
# 13391  budiman gabung prabowo cari cuan lunasin hutan...
# 13392  kayak produk beta pendek banget gue menunduk r...
# 13393  blue bulan viralvideo mahasiswa fakultas ilmu ...
# 13394  setelan tunik wanita hijab bahan babytery blue...
# 13395  ganjar membangun ikn lan hilirisasi warisan jo...
#
# [8766 rows x 2 columns]

# %%
def normalize_alay2(text):
    return ' '.join([alay_dict_map2[word] if word in alay_dict_map2 else word for word in text.split(' ')])
dataset["preprocessed"] = dataset.preprocessed.apply(lambda text: normalize_alay2(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      posting jadwal yang kacau tolong pembaruan ten...
# 1      volume penumpang kereta listrik commuter line ...
# 2      kereta listrik sih habis kereta cepat whoosh n...
# 3      sekelas belum bedakan gambar light rail transi...
# 4      tarif light rail transit jabodebek dijamin tid...
# ...                                                  ...
# 13391  budiman gabung prabowo cari cuan lunasin hutan...
# 13392  mirip  produk beta pendek sekali  saya menundu...
# 13393  blue bulan viralvideo mahasiswa fakultas ilmu ...
# 13394  setelan tunik wanita hijab bahan babytery blue...
# 13395  ganjar membangun ikn lan hilirisasi warisan jo...
#
# [8766 rows x 2 columns]

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
def stemming(text):
    return stemmer.stem(text)
dataset["preprocessed"] = dataset.preprocessed.apply(lambda text: stemming(text))
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed
# 0      posting jadwal yang kacau tolong baru tentang ...
# 1      volume tumpang kereta listrik commuter line ti...
# 2      kereta listrik sih habis kereta cepat whoosh n...
# 3      kelas belum beda gambar light rail transit jak...
# 4      tarif light rail transit jabodebek jamin tidak...
# ...                                                  ...
# 13391  budiman gabung prabowo cari cuan lunasin hutan...
# 13392  mirip produk beta pendek sekali saya tunduk re...
# 13393  blue bulan viralvideo mahasiswa fakultas ilmu ...
# 13394  setel tunik wanita hijab bahan babytery blue b...
# 13395  ganjar bangun ikn lan hilir waris jokowi jawa ...
#
# [8766 rows x 2 columns]

# %%
def tokenizingText(text): # Tokenizing or splitting a string, text into a list of tokens
    text = word_tokenize(text)
    return text
dataset['tokenizing'] = dataset['preprocessed'].apply(tokenizingText)
dataset
# Out:
#                                                    Tweet  \
# 0      @lrtjabodebek Selain posting jadwal yg kacau i...
# 1      Volume atau jumlah penumpang KRL Commuter Line...
# 2      @nadsfathinah sebenarnya bukan naik krl sih ka...
# 3      Sekelas @cnbcindonesia @CNNIndonesia masih bel...
# 4      Tarif LRT Jabodebek Dijamin Gak Naik Tahun Ini...
# ...                                                  ...
# 13391  Pantas saja Budiman gabung prabowo untuk cari ...
# 13392  kek produk beta: (-) pendek banget gw harus nu...
# 13393  Blue Moon #viralvideo Mahasiswa FISIP UI Inka ...
# 13394  SETELAN TUNIK WANITA HIJAB BAHAN BABYTERY http...
# 13395  Ganjar bakal terus mbangun IKN lan hilirisasi ...
#
#                                             preprocessed  \
# 0      posting jadwal yang kacau tolong baru tentang ...
# 1      volume tumpang kereta listrik commuter line ti...
# 2      kereta listrik sih habis kereta cepat whoosh n...
# 3      kelas belum beda gambar light rail transit jak...
# 4      tarif light rail transit jabodebek jamin tidak...
# ...                                                  ...
# 13391  budiman gabung prabowo cari cuan lunasin hutan...
# 13392  mirip produk beta pendek sekali saya tunduk re...
# 13393  blue bulan viralvideo mahasiswa fakultas ilmu ...
# 13394  setel tunik wanita hijab bahan babytery blue b...
# 13395  ganjar bangun ikn lan hilir waris jokowi jawa ...
#
#                                               tokenizing
# 0      [posting, jadwal, yang, kacau, tolong, baru, t...
# 1      [volume, tumpang, kereta, listrik, commuter, l...
# 2      [kereta, listrik, sih, habis, kereta, cepat, w...
# 3      [kelas, belum, beda, gambar, light, rail, tran...
# 4      [tarif, light, rail, transit, jabodebek, jamin...
# ...                                                  ...
# 13391  [budiman, gabung, prabowo, cari, cuan, lunasin...
# 13392  [mirip, produk, beta, pendek, sekali, saya, tu...
# 13393  [blue, bulan, viralvideo, mahasiswa, fakultas,...
# 13394  [setel, tunik, wanita, hijab, bahan, babytery,...
# 13395  [ganjar, bangun, ikn, lan, hilir, waris, jokow...
#
# [8766 rows x 3 columns]

# %%
# Determine sentiment polarity of tweets using indonesia sentiment lexicon (source : https://github.com/fajri91/InSet)
# Loads lexicon positive and negative data
lexicon_positive = dict()
import csv
with open('/content/drive/MyDrive/pemrosesan text/project/lexicon_positive.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_positive[row[0]] = int(row[1])

lexicon_negative = dict()
import csv
with open('/content/drive/MyDrive/pemrosesan text/project/lexicon_negative.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_negative[row[0]] = int(row[1])

# Function to determine sentiment polarity of tweets
def sentiment_analysis_lexicon_indonesia(text):
    #for word in text:
    score = 0
    for word in text:
        if (word in lexicon_positive):
            score = score + lexicon_positive[word]
    for word in text:
        if (word in lexicon_negative):
            score = score + lexicon_negative[word]
    polarity=''
    if (score > 0):
        polarity = 'positive'
    elif (score < 0):
        polarity = 'negative'
    else:
        polarity = 'neutral'
    return score, polarity
results = dataset['tokenizing'].apply(sentiment_analysis_lexicon_indonesia)
results = list(zip(*results))
dataset['polarity_score'] = results[0]
dataset['polarity'] = results[1]
print(dataset['polarity'].value_counts())
# Out:
# negative    6262
# positive    1793
# neutral      711
# Name: polarity, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (6, 6))
sizes = [count for count in dataset['polarity'].value_counts()]
labels = list(dataset['polarity'].value_counts().index)
explode = (0.1, 0, 0)
ax.pie(x = sizes, labels = labels, autopct = '%1.1f%%', explode = explode, textprops={'fontsize': 10})
ax.set_title('Sentiment Polarity on Twitter \n (total = 8021 comments)', fontsize = 11, pad = 20)
plt.show()

# %%
pd.set_option('display.max_colwidth', 3000)
positive_comments = dataset[dataset['polarity'] == 'positive']
positive_comments = positive_comments[['preprocessed', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=False).reset_index(drop = True)
positive_comments.index += 1
positive_comments[122:130]
# Out:
#                                                                                                                                                                                                                                                                                                                                preprocessed  \
# 123                                                                                                                                                                           logo representasi layan light rail transit jabodebek moda transportasi massal modern light rail transit jabodebek operasi masinis otomatis awas pusat kendali
# 124                                                                                                                                                                                                                  foto pt kamu luncur logo layan light rail transit jabodebek tuju kenal masyarakat target operasi juli foto dok pt kamu
# 125                                                                                                                                                                           logo representasi layan light rail transit jabodebek moda transportasi massal modern light rail transit jabodebek operasi masinis otomatis awas pusat kendali
# 126  alhamdulillah baik rabu blue bulan malam maudy ayunda inka selingkuh aparatur sipil negara amrabat to manchester united krunic well come back ciput pinpri gacor fakultas ilmu sosial dan ilmu politik oi mahasiswa evnne is coming palmer light rail transit jabodebek genoa lorrient van deh beek pakeajadulu viralvideo timasu mufc
# 127                                                                                                                                                                                                                                                            kamu karyawan jelang operasi light rail transit jabodebek yuk detikers apply
# 128                                                                                                                                                                                                                              always baju merah the hero one kes kereta itu baju merah selamat now at light rail transit baju merah hihi
# 129                                                                                                                                                                operator light rail transit jakarta layan rute stasiun gangsa velodrome beda light rail transit jabodebek kait langsung konfirmasi akun sosial media terima kasih senyum
# 130                                                                                                                                                                    halo kak selamat malam mohon maaf kak light rail transit jakarta operator beda light rail transit jabodebek informasi langsung konfirmasi ya kak terima kasih senyum
#
#      polarity_score  polarity
# 123              11  positive
# 124              11  positive
# 125              11  positive
# 126              11  positive
# 127              11  positive
# 128              11  positive
# 129              11  positive
# 130              11  positive

# %%
pd.set_option('display.max_colwidth', 3000)
positive_comments = dataset[dataset['polarity'] == 'negative']
positive_comments = positive_comments[['preprocessed', 'polarity_score', 'polarity']].sort_values(by = 'polarity_score', ascending=False).reset_index(drop = True)
positive_comments.index += 1
positive_comments[200:210]
# Out:
#                                                                                                                                                  preprocessed  \
# 201                                         hi teman raina kereta light rail transit jabodebek pahlawan lah tahu yuk simak lrtjabodebek smarttravellivebetter
# 202                                                   taman mini indonesia indah light rail transit dukuh turun light rail transit ganti kereta mrt blok sama
# 203                                                                                                               light rail transit mrt kereta api tawa lucu
# 204                                                                                                          mon maaf bang presiden bilang cari kesalahanmaaf
# 205  cuma saja digo friends sudah light rail transit jabodebek resmi presiden joko widodo tahu rute rute cek video ayo digoid light rail transit lrtjabodebek
# 206                                                                                                                      light rail transit kereta cepat foto
# 207                                                           halo kak selamat pagi mohon maaf kak informasi light rail transit jabodebek beda operator usaha
# 208                                                       presiden light rail transit jabodebek buru buru operasional evaluasi jokowi lrtjabodebek ericthohir
# 209                                                                   l light rail transit panjang light light light rail transit alias kereta transit ringan
# 210        aduh jadwal operasi light rail transit jabodebek mundur tahun light rail transit lrtjabodebek jadwaloperasilrt operasilrt infrastrukturjabodetabek
#
#      polarity_score  polarity
# 201              -1  negative
# 202              -1  negative
# 203              -1  negative
# 204              -1  negative
# 205              -1  negative
# 206              -1  negative
# 207              -1  negative
# 208              -1  negative
# 209              -1  negative
# 210              -1  negative

# %%
# Visualize word cloud
list_words=''
for comment in dataset['tokenizing']:
    for word in comment:
        list_words += ' '+(word)

wordcloud = WordCloud(width = 600, height = 400, background_color = 'black', min_font_size = 10).generate(list_words)
fig, ax = plt.subplots(figsize = (8, 6))
ax.set_title('Word Cloud of Comments Data', fontsize = 18)
ax.grid(False)
ax.imshow((wordcloud))
fig.tight_layout(pad=0)
ax.axis('off')
plt.show()

# %%
# Function to group all positive/negative words
def words_with_sentiment(text):
    positive_words=[]
    negative_words=[]
    for word in text:
        score_pos = 0
        score_neg = 0
        if (word in lexicon_positive):
            score_pos = lexicon_positive[word]
        if (word in lexicon_negative):
            score_neg = lexicon_negative[word]

        if (score_pos + score_neg > 0):
            positive_words.append(word)
        elif (score_pos + score_neg < 0):
            negative_words.append(word)

    return positive_words, negative_words
# Visualize positive and negative word cloud
sentiment_words = dataset['tokenizing'].apply(words_with_sentiment)
sentiment_words = list(zip(*sentiment_words))
positive_words = sentiment_words[0]
negative_words = sentiment_words[1]

fig, ax = plt.subplots(1, 2,figsize = (12, 10))
list_words_postive=''
for row_word in positive_words:
    for word in row_word:
        list_words_postive += ' '+(word)
wordcloud_positive = WordCloud(width = 800, height = 600, background_color = 'black', colormap = 'Greens'
                               , min_font_size = 10).generate(list_words_postive)
ax[0].set_title('Word Cloud of Positive Words on comments Data \n (based on Indonesia Sentiment Lexicon)', fontsize = 14)
ax[0].grid(False)
ax[0].imshow((wordcloud_positive))
fig.tight_layout(pad=0)
ax[0].axis('off')

list_words_negative=''
for row_word in negative_words:
    for word in row_word:
        list_words_negative += ' '+(word)
wordcloud_negative = WordCloud(width = 800, height = 600, background_color = 'black', colormap = 'Reds'
                               , min_font_size = 10).generate(list_words_negative)
ax[1].set_title('Word Cloud of Negative Words on comments Data \n (based on Indonesia Sentiment Lexicon)', fontsize = 14)
ax[1].grid(False)
ax[1].imshow((wordcloud_negative))
fig.tight_layout(pad=0)
ax[1].axis('off')

plt.show()

# %%
fasttext = gensim.models.fasttext.load_facebook_model("/content/drive/MyDrive/pemrosesan text/project/Fastext_model_tweet.bin")
print("Ada %s vektor kata yang ditemukan dalam model FastText" % len(fasttext.wv))
# Out:
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2'; replacing invalid characters, using '\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe5'; replacing invalid characters, using '\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe3'; replacing invalid characters, using '\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xeb'; replacing invalid characters, using '\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2'; replacing invalid characters, using 'x9c\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf4'; replacing invalid characters, using '\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xe2'; replacing invalid characters, using 'x98\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe2'; replacing invalid characters, using 'x99\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9d\xe3'; replacing invalid characters, using 'x9d\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9a\xe3'; replacing invalid characters, using 'x9a\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xba'; replacing invalid characters, using 'x98\\xba'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf0'; replacing invalid characters, using '\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9d\xe2'; replacing invalid characters, using 'x9d\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe5'; replacing invalid characters, using 'x9c\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe2'; replacing invalid characters, using 'x8f\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf3'; replacing invalid characters, using '\\xf3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe3'; replacing invalid characters, using 'x8f\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'xad\xe3'; replacing invalid characters, using 'xad\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8d\xe3'; replacing invalid characters, using 'x8d\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf2'; replacing invalid characters, using '\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x82\xe2'; replacing invalid characters, using 'x82\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'xa0\xe3'; replacing invalid characters, using 'xa0\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x92\xe2'; replacing invalid characters, using 'x92\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x96\xbd'; replacing invalid characters, using 'x96\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xeb'; replacing invalid characters, using 'x9c\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xbe'; replacing invalid characters, using 'x80\\xbe'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe0'; replacing invalid characters, using '\\xe0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x93\xe3'; replacing invalid characters, using 'x93\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9e\xe2'; replacing invalid characters, using 'x9e\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8d\xe2'; replacing invalid characters, using 'x8d\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf5'; replacing invalid characters, using '\\xf5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe6'; replacing invalid characters, using '\\xe6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kawan\xf2'; replacing invalid characters, using 'kawan\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x93\xe2'; replacing invalid characters, using 'x93\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xbe\xe2'; replacing invalid characters, using 'x80\\xbe\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x81\xe3'; replacing invalid characters, using 'x81\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'client\xf3\xb3'; replacing invalid characters, using 'client\\xf3\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'starla\xf2'; replacing invalid characters, using 'starla\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe3'; replacing invalid characters, using 'x9c\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x92\xe3'; replacing invalid characters, using 'x92\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe5'; replacing invalid characters, using 'x99\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x94\xe2'; replacing invalid characters, using 'x94\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x82\xe2\xb2'; replacing invalid characters, using 'x82\\xe2\\xb2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe5\xbd\xe2'; replacing invalid characters, using '\\xe5\\xbd\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8b\xe2'; replacing invalid characters, using 'x8b\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xef'; replacing invalid characters, using '\\xef'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xee'; replacing invalid characters, using '\\xee'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe5\xbe\xe2'; replacing invalid characters, using '\\xe5\\xbe\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'xa0\xe2'; replacing invalid characters, using 'xa0\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf6'; replacing invalid characters, using '\\xf6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xb9'; replacing invalid characters, using 'x80\\xb9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x90\xe2'; replacing invalid characters, using 'x90\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9e\xe3'; replacing invalid characters, using 'x9e\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sayang\xe2'; replacing invalid characters, using 'sayang\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xe5'; replacing invalid characters, using 'x98\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'xad\xe2'; replacing invalid characters, using 'xad\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'getawain\xf4'; replacing invalid characters, using 'getawain\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'laj\xe2'; replacing invalid characters, using 'laj\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xb9\xe3'; replacing invalid characters, using 'x80\\xb9\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9a\xe2'; replacing invalid characters, using 'x9a\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x96\xbe'; replacing invalid characters, using 'x96\\xbe'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kadang\xf2'; replacing invalid characters, using 'kadang\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe5\xbd'; replacing invalid characters, using 'x9c\\xe5\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'_\xe2'; replacing invalid characters, using '_\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'd\xe2'; replacing invalid characters, using 'd\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x90\xe3'; replacing invalid characters, using 'x90\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x86\xe3'; replacing invalid characters, using 'x86\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x82\xf0'; replacing invalid characters, using 'x82\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x94\xe3'; replacing invalid characters, using 'x94\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'di\xe3'; replacing invalid characters, using 'di\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'baik\xf4'; replacing invalid characters, using 'baik\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe5\xbd\xe3'; replacing invalid characters, using 'x9c\\xe5\\xbd\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xe3'; replacing invalid characters, using 'x98\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'20\xfa'; replacing invalid characters, using '20\\xfa'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'diam\xf5'; replacing invalid characters, using 'diam\\xf5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sedap\xf2'; replacing invalid characters, using 'sedap\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x93\xe5'; replacing invalid characters, using 'x93\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ma\xf3\xb2uf'; replacing invalid characters, using 'ma\\xf3\\xb2uf'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'cinta\xf4'; replacing invalid characters, using 'cinta\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'nga\xe2'; replacing invalid characters, using 'nga\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf8'; replacing invalid characters, using '\\xf8'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x83\xe2'; replacing invalid characters, using 'x83\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dan\xe3'; replacing invalid characters, using 'dan\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'awaitu\xf2'; replacing invalid characters, using 'awaitu\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe6'; replacing invalid characters, using 'x9c\\xe6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'wedges\xe2'; replacing invalid characters, using 'wedges\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xba\xe3'; replacing invalid characters, using 'x9c\\xe2\\xba\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ape\xf5'; replacing invalid characters, using 'ape\\xf5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe2\xaa\xe3'; replacing invalid characters, using 'x99\\xe2\\xaa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'da\xe2'; replacing invalid characters, using 'da\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'yang\xe3'; replacing invalid characters, using 'yang\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kita\xe2'; replacing invalid characters, using 'kita\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'cinta\xe2'; replacing invalid characters, using 'cinta\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xef\xbd'; replacing invalid characters, using '\\xef\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'pagi\xe2'; replacing invalid characters, using 'pagi\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xba'; replacing invalid characters, using 'x80\\xba'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ngetawain\xe2'; replacing invalid characters, using 'ngetawain\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x81\xe2'; replacing invalid characters, using 'x81\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe6'; replacing invalid characters, using 'x99\\xe6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'boleh\xe2'; replacing invalid characters, using 'boleh\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'fateh\xf4'; replacing invalid characters, using 'fateh\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kuli\xe2'; replacing invalid characters, using 'kuli\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe5\xbd\xe3'; replacing invalid characters, using 'x99\\xe5\\xbd\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x92\xe5'; replacing invalid characters, using 'x92\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'i\xf3'; replacing invalid characters, using 'i\\xf3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xec'; replacing invalid characters, using '\\xec'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x96\xbc'; replacing invalid characters, using 'x96\\xbc'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'xa0\xf4'; replacing invalid characters, using 'xa0\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ya\xe2'; replacing invalid characters, using 'ya\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'b\xe2'; replacing invalid characters, using 'b\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x92\xe2\xbc\xe3'; replacing invalid characters, using 'x92\\xe2\\xbc\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf9'; replacing invalid characters, using '\\xf9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xef\xbc'; replacing invalid characters, using '\\xef\\xbc'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b't\xe2'; replacing invalid characters, using 't\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sayang\xe3'; replacing invalid characters, using 'sayang\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xfb'; replacing invalid characters, using '\\xfb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dimenangi\xf4'; replacing invalid characters, using 'dimenangi\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x92\xe2\xb9'; replacing invalid characters, using 'x92\\xe2\\xb9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x96\xbd\xe2'; replacing invalid characters, using 'x96\\xbd\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x93\xe2\xaa'; replacing invalid characters, using 'x93\\xe2\\xaa'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xeb'; replacing invalid characters, using 'x98\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'di\xe2'; replacing invalid characters, using 'di\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x87\xe2'; replacing invalid characters, using 'x87\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xba\xe2'; replacing invalid characters, using 'x80\\xba\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8b\xe3'; replacing invalid characters, using 'x8b\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xba\xe2'; replacing invalid characters, using 'x98\\xba\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xb2'; replacing invalid characters, using 'x9c\\xe2\\xb2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'in\xe2'; replacing invalid characters, using 'in\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'masing\xf2'; replacing invalid characters, using 'masing\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xba\xe3'; replacing invalid characters, using 'x80\\xba\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'halaaaa\xf4'; replacing invalid characters, using 'halaaaa\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xeb'; replacing invalid characters, using 'x99\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ay\xe2'; replacing invalid characters, using 'ay\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe5\xbe'; replacing invalid characters, using 'x9c\\xe5\\xbe'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9cngetawain\xe2'; replacing invalid characters, using 'x9cngetawain\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xaa'; replacing invalid characters, using 'x99\\xaa'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bahagia\xf4'; replacing invalid characters, using 'bahagia\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'laya\xe2'; replacing invalid characters, using 'laya\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'untuk\xe3'; replacing invalid characters, using 'untuk\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'xa0\xf6'; replacing invalid characters, using 'xa0\\xf6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'saya\xe3'; replacing invalid characters, using 'saya\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe2\xaa'; replacing invalid characters, using 'x99\\xe2\\xaa'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ini\xe3'; replacing invalid characters, using 'ini\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe3'; replacing invalid characters, using 'x99\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8d\xe6'; replacing invalid characters, using 'x8d\\xe6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dengan\xe3'; replacing invalid characters, using 'dengan\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe2\xbc\xe3'; replacing invalid characters, using 'x8f\\xe2\\xbc\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dan\xe2'; replacing invalid characters, using 'dan\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'nampa\xe2'; replacing invalid characters, using 'nampa\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xaa'; replacing invalid characters, using 'x9c\\xe2\\xaa'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'_\xf5'; replacing invalid characters, using '_\\xf5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hati\xf4'; replacing invalid characters, using 'hati\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kencing\xe2'; replacing invalid characters, using 'kencing\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe5\xbe\xe3'; replacing invalid characters, using 'x99\\xe5\\xbe\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xba'; replacing invalid characters, using 'x9c\\xe2\\xba'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'yang\xe2'; replacing invalid characters, using 'yang\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xf0'; replacing invalid characters, using 'x8f\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ma\xe2'; replacing invalid characters, using 'ma\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'k\xe2'; replacing invalid characters, using 'k\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'waktu\xf4'; replacing invalid characters, using 'waktu\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xb2\xe3'; replacing invalid characters, using '\\xe2\\xb2\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'm\xe3'; replacing invalid characters, using 'm\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ya\xe3'; replacing invalid characters, using 'ya\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xba\xe3'; replacing invalid characters, using '\\xe2\\xba\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'men\xe2'; replacing invalid characters, using 'men\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'aku\xf4'; replacing invalid characters, using 'aku\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'menjadi\xe3'; replacing invalid characters, using 'menjadi\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe5\xbe'; replacing invalid characters, using 'x99\\xe5\\xbe'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'xad\xf0'; replacing invalid characters, using 'xad\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe2\xb5'; replacing invalid characters, using 'x99\\xe2\\xb5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xef\xbe'; replacing invalid characters, using '\\xef\\xbe'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe4'; replacing invalid characters, using '\\xe4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'mendinga\xe2'; replacing invalid characters, using 'mendinga\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x86\xe2'; replacing invalid characters, using 'x86\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe2\xbc'; replacing invalid characters, using 'x8f\\xe2\\xbc'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x94\xb9'; replacing invalid characters, using 'x94\\xb9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x97\xbe'; replacing invalid characters, using 'x97\\xbe'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'orang\xe3'; replacing invalid characters, using 'orang\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8d\xe5'; replacing invalid characters, using 'x8d\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xe2'; replacing invalid characters, using 'x80\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'1\xe3'; replacing invalid characters, using '1\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'i\xe3'; replacing invalid characters, using 'i\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'yg\xe3'; replacing invalid characters, using 'yg\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xbc\xe2'; replacing invalid characters, using '\\xe2\\xbc\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'anyak\xf4'; replacing invalid characters, using 'anyak\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kamu\xe3'; replacing invalid characters, using 'kamu\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xaa\xe3'; replacing invalid characters, using '\\xe2\\xaa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'baik\xe3'; replacing invalid characters, using 'baik\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x86\xe5'; replacing invalid characters, using 'x86\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kerja\xe2'; replacing invalid characters, using 'kerja\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'masak\xe2'; replacing invalid characters, using 'masak\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9d\xe5'; replacing invalid characters, using 'x9d\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x97\xe2'; replacing invalid characters, using 'x97\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'k\xe3'; replacing invalid characters, using 'k\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'lain\xf4'; replacing invalid characters, using 'lain\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xaa'; replacing invalid characters, using '\\xe2\\xaa'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sa\xe2'; replacing invalid characters, using 'sa\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xba\xe2\xb5\xe3'; replacing invalid characters, using 'x80\\xba\\xe2\\xb5\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kita\xe3'; replacing invalid characters, using 'kita\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'warna\xe3'; replacing invalid characters, using 'warna\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sedih\xf4'; replacing invalid characters, using 'sedih\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe5\xbd\xe5'; replacing invalid characters, using '\\xe5\\xbd\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe6'; replacing invalid characters, using 'x8f\\xe6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dalam\xe3'; replacing invalid characters, using 'dalam\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'a\xe2'; replacing invalid characters, using 'a\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tengok\xe2'; replacing invalid characters, using 'tengok\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xb9\xe3'; replacing invalid characters, using 'x9c\\xe2\\xb9\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x83\xbd'; replacing invalid characters, using 'x83\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'that\xf3\xb3'; replacing invalid characters, using 'that\\xf3\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'don\xf3'; replacing invalid characters, using 'don\\xf3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'aja\xe3'; replacing invalid characters, using 'aja\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'cinta\xe3'; replacing invalid characters, using 'cinta\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe0\xb9'; replacing invalid characters, using '\\xe0\\xb9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xb9'; replacing invalid characters, using 'x9c\\xe2\\xb9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bisa\xe3'; replacing invalid characters, using 'bisa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'm\xe2'; replacing invalid characters, using 'm\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'h\xe2'; replacing invalid characters, using 'h\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'juga\xe3'; replacing invalid characters, using 'juga\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'a\xe3'; replacing invalid characters, using 'a\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'indonesia\xe3'; replacing invalid characters, using 'indonesia\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'beli\xe3'; replacing invalid characters, using 'beli\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'perawatan\xe3'; replacing invalid characters, using 'perawatan\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'p\xe2'; replacing invalid characters, using 'p\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bag\xe2'; replacing invalid characters, using 'bag\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ini\xe2'; replacing invalid characters, using 'ini\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kiki\xe2'; replacing invalid characters, using 'kiki\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xea'; replacing invalid characters, using '\\xea'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe3\xaa\xe2'; replacing invalid characters, using '\\xe3\\xaa\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8c\xe2'; replacing invalid characters, using 'x8c\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hati\xf2'; replacing invalid characters, using 'hati\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'nih\xe3'; replacing invalid characters, using 'nih\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'se\xe2'; replacing invalid characters, using 'se\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ga\xe2'; replacing invalid characters, using 'ga\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hari\xe3'; replacing invalid characters, using 'hari\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'itu\xe3'; replacing invalid characters, using 'itu\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xf1'; replacing invalid characters, using '\\xf1'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'lagi\xe3'; replacing invalid characters, using 'lagi\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'nya\xe3'; replacing invalid characters, using 'nya\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xbd'; replacing invalid characters, using 'x9c\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'jiwa\xf4'; replacing invalid characters, using 'jiwa\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'it\xf3\xb3'; replacing invalid characters, using 'it\\xf3\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'yg\xe2'; replacing invalid characters, using 'yg\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x95\xe2'; replacing invalid characters, using 'x95\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'itu\xe2'; replacing invalid characters, using 'itu\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'aku\xe3'; replacing invalid characters, using 'aku\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8e\xf9'; replacing invalid characters, using 'x8e\\xf9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'su\xe2'; replacing invalid characters, using 'su\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ap\xe2'; replacing invalid characters, using 'ap\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xb3'; replacing invalid characters, using 'x9c\\xe2\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'akan\xe3'; replacing invalid characters, using 'akan\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'pengalaman\xe3'; replacing invalid characters, using 'pengalaman\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x88\xe2'; replacing invalid characters, using 'x88\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x99\xe5\xbd'; replacing invalid characters, using 'x99\\xe5\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'itu\xf4'; replacing invalid characters, using 'itu\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'mara\xe2'; replacing invalid characters, using 'mara\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xb3\xe3'; replacing invalid characters, using 'x9c\\xe2\\xb3\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xb9\xe2'; replacing invalid characters, using 'x80\\xb9\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kami\xe3'; replacing invalid characters, using 'kami\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x84\xe2'; replacing invalid characters, using 'x84\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ada\xe3'; replacing invalid characters, using 'ada\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x89\xe2'; replacing invalid characters, using 'x89\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'wa\xe3'; replacing invalid characters, using 'wa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'yaa\xe3'; replacing invalid characters, using 'yaa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xbe'; replacing invalid characters, using '\\xe2\\xbe'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x81\xf0'; replacing invalid characters, using 'x81\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'anda\xe3'; replacing invalid characters, using 'anda\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x96\xba'; replacing invalid characters, using 'x96\\xba'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xed'; replacing invalid characters, using '\\xed'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8b\xf0'; replacing invalid characters, using 'x8b\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xaa\xe3'; replacing invalid characters, using 'x9c\\xe2\\xaa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe2\xb5\xe3'; replacing invalid characters, using 'x9c\\xe2\\xb5\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xe2\xb9\xe3'; replacing invalid characters, using 'x98\\xe2\\xb9\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'seperti\xe3'; replacing invalid characters, using 'seperti\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8c\xf0'; replacing invalid characters, using 'x8c\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'i\xe2'; replacing invalid characters, using 'i\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'aku\xe2'; replacing invalid characters, using 'aku\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'satan\xf3\xb3'; replacing invalid characters, using 'satan\\xf3\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bisa\xe2'; replacing invalid characters, using 'bisa\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sendiri\xe2'; replacing invalid characters, using 'sendiri\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ke\xe2'; replacing invalid characters, using 'ke\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xbd'; replacing invalid characters, using '\\xe2\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'd\xe3'; replacing invalid characters, using 'd\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xbd\xeb'; replacing invalid characters, using '\\xe2\\xbd\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'lebih\xe3'; replacing invalid characters, using 'lebih\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'o\xe2'; replacing invalid characters, using 'o\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dari\xe3'; replacing invalid characters, using 'dari\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'aja\xe2'; replacing invalid characters, using 'aja\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xf0'; replacing invalid characters, using 'x98\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sama\xe3'; replacing invalid characters, using 'sama\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dia\xe3'; replacing invalid characters, using 'dia\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b's\xe2'; replacing invalid characters, using 's\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'it\xe3'; replacing invalid characters, using 'it\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x84\xf9'; replacing invalid characters, using 'x84\\xf9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'aw\xe2'; replacing invalid characters, using 'aw\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'nya\xe2'; replacing invalid characters, using 'nya\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xbeo\xe2'; replacing invalid characters, using 'x80\\xbeo\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x86\xeb'; replacing invalid characters, using 'x86\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bahagia\xe2'; replacing invalid characters, using 'bahagia\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'banget\xe3'; replacing invalid characters, using 'banget\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xba1997'; replacing invalid characters, using 'x80\\xba1997'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'alhamdulillah\xe3'; replacing invalid characters, using 'alhamdulillah\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'pe\xe2'; replacing invalid characters, using 'pe\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ada\xe2'; replacing invalid characters, using 'ada\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xb5\xe3'; replacing invalid characters, using '\\xe2\\xb5\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xe5\xbe\xe3'; replacing invalid characters, using 'x9c\\xe5\\xbe\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x90\xe2\xb9'; replacing invalid characters, using 'x90\\xe2\\xb9'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'2\xe3'; replacing invalid characters, using '2\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9b\xbc'; replacing invalid characters, using 'x9b\\xbc'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xb3'; replacing invalid characters, using '\\xe2\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tu\xe2'; replacing invalid characters, using 'tu\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sendiri\xe3'; replacing invalid characters, using 'sendiri\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'info\xe3'; replacing invalid characters, using 'info\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'19\xe3'; replacing invalid characters, using '19\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'3\xe3'; replacing invalid characters, using '3\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9d\xeb'; replacing invalid characters, using 'x9d\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ka\xe2'; replacing invalid characters, using 'ka\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xb9\xe2'; replacing invalid characters, using '\\xe2\\xb9\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe2\xbd\xe3'; replacing invalid characters, using 'x8f\\xe2\\xbd\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'duit\xe2'; replacing invalid characters, using 'duit\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'2018\xe3'; replacing invalid characters, using '2018\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x91\xe2'; replacing invalid characters, using 'x91\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kamu\xe2'; replacing invalid characters, using 'kamu\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'morning\xe2'; replacing invalid characters, using 'morning\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hj\xf3\xb3'; replacing invalid characters, using 'hj\\xf3\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x92\xeb'; replacing invalid characters, using 'x92\\xeb'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'pada\xe3'; replacing invalid characters, using 'pada\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'n\xe2'; replacing invalid characters, using 'n\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xe2\xb5'; replacing invalid characters, using 'x98\\xe2\\xb5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'jaketmurah\xe3'; replacing invalid characters, using 'jaketmurah\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x98\xe2\xaa\xe3'; replacing invalid characters, using 'x98\\xe2\\xaa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tapi\xe2'; replacing invalid characters, using 'tapi\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tidak\xe3'; replacing invalid characters, using 'tidak\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8e\xf8'; replacing invalid characters, using 'x8e\\xf8'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kesempatan\xe3'; replacing invalid characters, using 'kesempatan\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xbd\xe3'; replacing invalid characters, using '\\xe2\\xbd\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'you\xe3'; replacing invalid characters, using 'you\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kamu\xf4'; replacing invalid characters, using 'kamu\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'lagi\xe2'; replacing invalid characters, using 'lagi\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe2\xbd'; replacing invalid characters, using 'x8f\\xe2\\xbd'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'gentar\xf4'; replacing invalid characters, using 'gentar\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'30\xe3'; replacing invalid characters, using '30\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sangat\xe2'; replacing invalid characters, using 'sangat\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'apa\xe3'; replacing invalid characters, using 'apa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kebencian\xf4'; replacing invalid characters, using 'kebencian\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe5\xbd\xe3'; replacing invalid characters, using '\\xe5\\xbd\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dedikasi\xf4'; replacing invalid characters, using 'dedikasi\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kota\xe3'; replacing invalid characters, using 'kota\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'birthday\xe3'; replacing invalid characters, using 'birthday\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x96\xba_\xe2'; replacing invalid characters, using 'x96\\xba_\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'takut\xe3'; replacing invalid characters, using 'takut\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kurikulummandarin\xe3'; replacing invalid characters, using 'kurikulummandarin\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sama\xe2'; replacing invalid characters, using 'sama\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x85\xf0'; replacing invalid characters, using 'x85\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x92\xe6'; replacing invalid characters, using 'x92\\xe6'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'aa\xea'; replacing invalid characters, using 'aa\\xea'
# ...
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tanya\xe3'; replacing invalid characters, using 'tanya\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe7'; replacing invalid characters, using '\\xe7'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'temen\xe3'; replacing invalid characters, using 'temen\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ah\xe2'; replacing invalid characters, using 'ah\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'desain\xe3'; replacing invalid characters, using 'desain\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hoax\xe3'; replacing invalid characters, using 'hoax\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x84\xb3'; replacing invalid characters, using 'x84\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tweps\xe2'; replacing invalid characters, using 'tweps\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'wey\xe2'; replacing invalid characters, using 'wey\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ucah\xf4'; replacing invalid characters, using 'ucah\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'rp\xe3'; replacing invalid characters, using 'rp\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'olshoppkp\xe3'; replacing invalid characters, using 'olshoppkp\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ternya\xe2'; replacing invalid characters, using 'ternya\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'telah\xe3'; replacing invalid characters, using 'telah\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'yaaa\xe3'; replacing invalid characters, using 'yaaa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hangat\xe3'; replacing invalid characters, using 'hangat\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'merde\xe2'; replacing invalid characters, using 'merde\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'cantikja\xe2'; replacing invalid characters, using 'cantikja\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bers\xe2'; replacing invalid characters, using 'bers\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'acah\xf2'; replacing invalid characters, using 'acah\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'22n\xe2'; replacing invalid characters, using '22n\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ma\xe3'; replacing invalid characters, using 'ma\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'sukses\xe2'; replacing invalid characters, using 'sukses\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kudo\xe2'; replacing invalid characters, using 'kudo\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'media\xe2'; replacing invalid characters, using 'media\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'pulang\xe2'; replacing invalid characters, using 'pulang\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'betul\xf2'; replacing invalid characters, using 'betul\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'theater\xe3'; replacing invalid characters, using 'theater\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xb3\xe2\xb3'; replacing invalid characters, using '\\xe2\\xb3\\xe2\\xb3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'best\xe3'; replacing invalid characters, using 'best\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'for\xe2'; replacing invalid characters, using 'for\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe2\xb9\xe3'; replacing invalid characters, using '\\xe2\\xb9\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9c\xaa'; replacing invalid characters, using 'x9c\\xaa'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'olong\xf4'; replacing invalid characters, using 'olong\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'begini\xe2'; replacing invalid characters, using 'begini\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'dimiliki\xf4'; replacing invalid characters, using 'dimiliki\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'salah\xe2'; replacing invalid characters, using 'salah\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'nyahati\xf2'; replacing invalid characters, using 'nyahati\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'selatan\xf0'; replacing invalid characters, using 'selatan\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'15\xe3'; replacing invalid characters, using '15\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'13\xe3'; replacing invalid characters, using '13\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'nanti\xe3'; replacing invalid characters, using 'nanti\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'semoga\xe2'; replacing invalid characters, using 'semoga\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hitam\xf5'; replacing invalid characters, using 'hitam\\xf5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'menjadi\xe2'; replacing invalid characters, using 'menjadi\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'instahappy\xe3'; replacing invalid characters, using 'instahappy\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xe5'; replacing invalid characters, using 'x8f\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tetap\xe3'; replacing invalid characters, using 'tetap\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ready\xe3'; replacing invalid characters, using 'ready\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'saudara\xf2'; replacing invalid characters, using 'saudara\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ya\xee'; replacing invalid characters, using 'ya\\xee'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kalian\xe2'; replacing invalid characters, using 'kalian\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kepada\xe3'; replacing invalid characters, using 'kepada\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xba\xe5'; replacing invalid characters, using 'x80\\xba\\xe5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'residence\xe3'; replacing invalid characters, using 'residence\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x8f\xbc\xf0'; replacing invalid characters, using 'x8f\\xbc\\xf0'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'20\xe2'; replacing invalid characters, using '20\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'guru\xe3'; replacing invalid characters, using 'guru\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'senin\xe2'; replacing invalid characters, using 'senin\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kembali\xe2'; replacing invalid characters, using 'kembali\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'pa\xe3'; replacing invalid characters, using 'pa\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'intropeksi\xe3'; replacing invalid characters, using 'intropeksi\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'jumpa\xf4'; replacing invalid characters, using 'jumpa\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ganteng\xe2'; replacing invalid characters, using 'ganteng\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x9b\xe2'; replacing invalid characters, using 'x9b\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'panjang\xe3'; replacing invalid characters, using 'panjang\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'e\xe2'; replacing invalid characters, using 'e\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bung\xe3'; replacing invalid characters, using 'bung\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kasih\xe2'; replacing invalid characters, using 'kasih\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hasil\xe3'; replacing invalid characters, using 'hasil\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'haha\xe3'; replacing invalid characters, using 'haha\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'mcm\xf2'; replacing invalid characters, using 'mcm\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tidur\xe2'; replacing invalid characters, using 'tidur\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'selama\xe3'; replacing invalid characters, using 'selama\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'diam\xf2'; replacing invalid characters, using 'diam\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'instalike\xe3'; replacing invalid characters, using 'instalike\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'berhasil\xe2'; replacing invalid characters, using 'berhasil\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x95\xed'; replacing invalid characters, using 'x95\\xed'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'photographer\xe3'; replacing invalid characters, using 'photographer\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'super\xe3'; replacing invalid characters, using 'super\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'cuma\xe2'; replacing invalid characters, using 'cuma\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'cinta\xf2'; replacing invalid characters, using 'cinta\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'\xe5\xbd\xe2\xbc\xe3'; replacing invalid characters, using '\\xe5\\xbd\\xe2\\xbc\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kadang\xe3'; replacing invalid characters, using 'kadang\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tua\xe3'; replacing invalid characters, using 'tua\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'mencintaimu\xf4'; replacing invalid characters, using 'mencintaimu\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'lakuin\xf4'; replacing invalid characters, using 'lakuin\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'guys\xe2'; replacing invalid characters, using 'guys\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'besok\xe2'; replacing invalid characters, using 'besok\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x80\xba\xe2\xb5'; replacing invalid characters, using 'x80\\xba\\xe2\\xb5'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'org\xe3'; replacing invalid characters, using 'org\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'lah\xe2'; replacing invalid characters, using 'lah\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'surabaya\xe3'; replacing invalid characters, using 'surabaya\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'layanan\xe3'; replacing invalid characters, using 'layanan\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'36\xe3'; replacing invalid characters, using '36\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'saja\xe2'; replacing invalid characters, using 'saja\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'umum\xe3'; replacing invalid characters, using 'umum\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'bapak\xe3'; replacing invalid characters, using 'bapak\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'manis\xe2'; replacing invalid characters, using 'manis\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hahaha\xe3'; replacing invalid characters, using 'hahaha\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'mencintaimu\xe2'; replacing invalid characters, using 'mencintaimu\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'semuanya\xe2'; replacing invalid characters, using 'semuanya\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'kuliner\xe3'; replacing invalid characters, using 'kuliner\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'on\xe2'; replacing invalid characters, using 'on\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'distance\xf4'; replacing invalid characters, using 'distance\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'biar\xe3'; replacing invalid characters, using 'biar\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'x91\xf2'; replacing invalid characters, using 'x91\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'budak\xf2'; replacing invalid characters, using 'budak\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'instagram\xe3'; replacing invalid characters, using 'instagram\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'instagood\xe3'; replacing invalid characters, using 'instagood\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'hebat\xe3'; replacing invalid characters, using 'hebat\\xe3'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'lulus\xe2'; replacing invalid characters, using 'lulus\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'ok\xf2'; replacing invalid characters, using 'ok\\xf2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'karyamu\xf4'; replacing invalid characters, using 'karyamu\\xf4'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'panjang\xe2'; replacing invalid characters, using 'panjang\\xe2'
# ERROR:gensim.models._fasttext_bin:failed to decode invalid unicode bytes b'tapi\xe3'; replacing invalid characters, using 'tapi\\xe3'
# Ada 69465 vektor kata yang ditemukan dalam model FastText

# %%
vectors = []
for text in dataset.preprocessed.values:
    word_embedding = []
    for word in text.split(" "):
        try:
            word_vec = fasttext.wv[word]
            word_embedding.append(word_vec)
        except:
            pass
    word_embedding = np.array(word_embedding)
    embeddings = np.mean(word_embedding, axis=0)
    vectors.append(embeddings)
vectors = np.array(vectors)
print("Dimensi dari fitur yang digunakan yaitu", (vectors.shape))
# Out:
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# WARNING:gensim.models.fasttext:could not extract any ngrams from '', returning origin vector
# Dimensi dari fitur yang digunakan yaitu (8766, 100)

# %%
X = vectors
Y = np.array(dataset.polarity)
figure, ax = plt.subplots(figsize=(7, 7))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=Y, ax=ax, palette="Spectral")
plt.show()

# %%
linear_svm = SVC(kernel="linear")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)
normalizer = Normalizer()
X_train = normalizer.fit_transform(X_train)
X_test = normalizer.transform(X_test)
print("Jumlah dari train data adalah", len(X_train))
print("\nSedangkan jumlah dari test data yaitu", len(X_test))
# Out:
# Jumlah dari train data adalah 7889
#
# Sedangkan jumlah dari test data yaitu 877

# %%
linear_svm.fit(X_train, Y_train)
filename = "/content/drive/MyDrive/pemrosesan text/project/SVMlinear_model.sav"
joblib.dump(linear_svm, filename)
# Out:
# ['/content/drive/MyDrive/pemrosesan text/project/SVMlinear_model.sav']

# %%
start = time()
loaded_model = joblib.load("/content/drive/MyDrive/pemrosesan text/project/SVMlinear_model.sav")
Y_pred = loaded_model.predict(X_test)
acc_score = accuracy_score(Y_test, Y_pred)
end = time()
elapsed = end - start

print("Akurasi yang dihasilkan  pada ekstraksi fitur fasttext adalah %.2f%%\n" % (acc_score*100))
print("Dan berikut merupakan hasil evaluasi secara keseluruhan:\n\n", classification_report(Y_test, Y_pred))
print("Lama waktu yang dibutuhkan untuk memproses yaitu %.2f detik." % (elapsed))
# Out:
# Akurasi yang dihasilkan  pada ekstraksi fitur fasttext adalah 79.02%
#
# Dan berikut merupakan hasil evaluasi secara keseluruhan:
#
#                precision    recall  f1-score   support
#
#     negative       0.79      0.97      0.87       613
#      neutral       0.71      0.14      0.24        69
#     positive       0.78      0.46      0.58       195
#
#     accuracy                           0.79       877
#    macro avg       0.76      0.52      0.56       877
# weighted avg       0.78      0.79      0.76       877
#
# Lama waktu yang dibutuhkan untuk memproses yaitu 0.19 detik.

# %%
figure, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(confusion_matrix(Y_test, Y_pred), annot=True, fmt="g", annot_kws={"size": 14}, cmap="vlag", cbar=False)
ax.set_xticklabels(["Negatif", "Positif", "Netral"], fontsize="14", rotation=90)
ax.set_yticklabels(["Negatif", "Positif", "Netral"], fontsize="14", rotation=0)
plt.show()

# %%
#dataset.to_csv("/content/drive/MyDrive/pemrosesan text/clean dataset.csv", index=False)
